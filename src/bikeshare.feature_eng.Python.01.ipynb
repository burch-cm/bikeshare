# %%
# basic data structures
import numpy as np
import pandas as pd
# keras
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasRegressor
# parquet data structure
import pyarrow as pa
import pyarrow.parquet as pq

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
dat = pq.read_table(".././data/bikeshare-data.parquet")

# %%
bikedata = dat.to_pandas()

# %%
bikedata.head(10)
# Out:
#     trip_date  trip_count  total_seconds   AWND  PRCP  SNOW  SNWD  TAVG  TMAX  \
# 0  2018-01-01        1099      1057878.0  11.63  0.00   0.0   0.0  19.0    26
# 1  2018-01-02        3796      2840648.0   7.83  0.00   0.0   0.0  18.0    26
# 2  2018-01-03        4742      3342920.0   3.80  0.00   0.0   0.0  23.0    35
# 3  2018-01-04        2359      1373034.0  19.91  0.10   0.8   1.2  26.0    27
# 4  2018-01-05        2735      1643926.0  15.66  0.00   0.0   1.2  17.0    21
# 5  2018-01-06        1510       965617.0  13.42  0.00   0.0   0.0  15.0    21
# 6  2018-01-07        1719      1153907.0   8.95  0.00   0.0   0.0  15.0    23
# 7  2018-01-08        4099      2725381.0   8.50  0.06   0.0   0.0  25.0    39
# 8  2018-01-09        6119      4649579.0   5.37  0.00   0.0   0.0  38.0    51
# 9  2018-01-10        7109      5293373.0   3.36  0.00   0.0   0.0  36.0    43
#
#    TMIN
# 0    13
# 1    13
# 2    13
# 3    16
# 4    13
# 5    11
# 6     8
# 7    19
# 8    30
# 9    27

# %%
bikedata['avg_trip_sec'] = bikedata.total_seconds / bikedata.trip_count
bikedata[['trip_date', 'avg_trip_sec']].head()
# Out:
#     trip_date  avg_trip_sec
# 0  2018-01-01    962.582348
# 1  2018-01-02    748.326660
# 2  2018-01-03    704.959933
# 3  2018-01-04    582.040695
# 4  2018-01-05    601.069835
